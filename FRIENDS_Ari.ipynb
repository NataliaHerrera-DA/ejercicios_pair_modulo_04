# %% [markdown]
# #### **FRIENDS**

# %% [markdown]
# EDA - VISUALIZACIONES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
df_episodes = pd.read_csv("./dataset_friends/friends_episodes_v3.csv", encoding="latin1")
df_episodes.head(1)
# Out:
#    Year_of_prod  Season  Episode Number  \
# 0          1994       1               1
#
#                                      Episode_Title  Duration  \
# 0  The One Where Monica Gets a Roommate: The Pilot        22
#
#                                              Summary       Director  Stars  \
# 0  Monica and the gang introduce Rachel to the "r...  James Burrows    8.3
#
#    Votes
# 0   7440

# %%
df_info = pd.read_csv("./dataset_friends/friends_info.csv")
df_info.head(1)
# Out:
#    season  episode      title    directed_by                    written_by  \
# 0       1        1  The Pilot  James Burrows  David Crane & Marta Kauffman
#
#      air_date  us_views_millions  imdb_rating
# 0  1994-09-22               21.5          8.3

# %%
df_quotes = pd.read_csv("./dataset_friends/friends_quotes.csv")
df_quotes.head(1)
# Out:
#    author  episode_number           episode_title  \
# 0  Monica             1.0  Monica Gets A Roommate
#
#                                                quote  quote_order  season
# 0  There's nothing to tell! He's just some guy I ...          0.0     1.0

# %%
df_episodes.columns
# Out:
# Index(['Year_of_prod', 'Season', 'Episode Number', 'Episode_Title', 'Duration',
#        'Summary', 'Director', 'Stars', 'Votes'],
#       dtype='object')

# %%
df_info.columns
# Out:
# Index(['season', 'episode', 'title', 'directed_by', 'written_by', 'air_date',
#        'us_views_millions', 'imdb_rating'],
#       dtype='object')

# %%
df_quotes.columns
# Out:
# Index(['author', 'episode_number', 'episode_title', 'quote', 'quote_order',
#        'season'],
#       dtype='object')

# %%
df_info['written_by'].nunique()
# Out:
# 102
